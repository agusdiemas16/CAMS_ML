# %%
import pandas
import matplotlib.pyplot as plt

#csv diambil dari http://localhost:8000/customerapp/csv

url = 'http://localhost:8000/customerapp/csv'
url

data = pandas.read_csv(url)
#data = pandas.read_csv('customerapp.csv')
data
# Out:
#               Nama         Gaji Jenis_Kelamin  Existing Occupation  \
# 0              Eko   25000000.0             L      True          N
# 1            Putri   15000000.0             P     False          F
# 2              Ari   30000000.0             L     False          N
# 3               as   50000000.0             L      True          N
# 4           Ariadi   20000000.0             L     False          N
# 5          Andrias  150000000.0             L     False          N
# 6         Suprapti    2000000.0             P      True          F
# 7          Subadri    2500000.0             L      True          F
# 8             Jobs   12000000.0             L     False          N
# 9             Anis    7500000.0             P      True          F
# 10            Bani   17500000.0             P      True          F
# 11            Boni    9000000.0             L      True          N
# 12            Sari    5500000.0             P      True          N
# ...

# %%
# %matplotlib inline

#a = data.Jenis_Kelamin.value_counts().plot()
#b = data.Gaji.value_counts().plot()
#c = data.Existing.value_counts().plot(kind='bar')
#d = data.Kendaraan.value_counts().plot()
#e = data.Occupation.value_counts().plot(kind='pie')

#aa = data.Jenis_Kelamin.plot()
bb = data.Gaji.plot(kind = 'line')
#cc = data.Existing.plot(kind='bar')
#dd = data.Kendaraan.plot()
#ee = data.Occupation.plot(kind='pie')

bb
